# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = np.load('pp_node_swap_sim_100_com.npy')

# %%
results.astype('float32').tofile('pp_node_swap_sim_100_com.dat')

# %%
results
# Out:
# array([[  1.10866667e-02,   9.01333333e-03,   7.28000000e-03,
#           6.18000000e-03,   5.00666667e-03,   4.24666667e-03,
#           2.94666667e-03,   2.64666667e-03,   1.78666667e-03,
#           1.22000000e-03,   1.24666667e-03,   7.46666667e-04,
#           5.66666667e-04,   4.73333333e-04,   3.26666667e-04,
#           1.46666667e-04,   1.00000000e-04,   8.66666667e-05,
#           6.66666667e-05,   7.33333333e-05,   4.66666667e-05],
#        [  3.93200000e-02,   3.18133333e-02,   2.59333333e-02,
#           2.19133333e-02,   1.71933333e-02,   1.40466667e-02,
#           1.00066667e-02,   8.58000000e-03,   6.04000000e-03,
#           4.27333333e-03,   3.16000000e-03,   2.18000000e-03,
#           1.58666667e-03,   1.34666667e-03,   9.20000000e-04,
#           5.13333333e-04,   3.46666667e-04,   2.20000000e-04,
#           1.60000000e-04,   1.46666667e-04,   8.66666667e-05],
#        [  8.44533333e-02,   7.50800000e-02,   6.57066667e-02,
# ...

# %%
plt.imshow(results)

# %%
len(results)
# Out:
# 20
