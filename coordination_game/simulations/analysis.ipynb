# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results_5v20 = np.load('cluster_cluster_p/edge_swap_5v20_mu03_p_scan.npy')
results_20v5 = np.load('cluster_cluster_p/edge_swap_20v5_mu03.npy')
results_node = np.load('cluster_cluster_p/node_swap_5v20_mu03.npy')

# %%
plt.plot(np.linspace(0, 10000, 80),np.average(results_20v5.T[len(results_20v5.T)-1].T, axis=0))

# %%
plt.plot(np.linspace(0, 1, len((results_node.T)[len(results_node.T)-1])),(results_node.T)[len(results_node.T)-1])
plt.plot(np.linspace(0, 1, 80),np.average(results_20v5.T[len(results_20v5.T)-1].T, axis=0))

# %% [raw]
# flip= results.T
# finalsize = flip[9]
#
# int_curve = np.cumsum(finalsize - np.average(finalsize[range(65,75)]))
# plt.semilogy(np.max(int_curve)-int_curve, 'b+')
