# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = np.load('cluster_cluster_p/edge_swap_20v5_mu03.npy')

# %%
plt.plot(finalsize - np.average(finalsize[range(50,79)]))

# %%
flip= results.T
finalsize = flip[9]

int_curve = np.cumsum(finalsize - np.average(finalsize[range(65,75)]))
plt.semilogy(np.max(int_curve)-int_curve, 'b+')
