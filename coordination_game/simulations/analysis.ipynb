# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = np.load('varyR/power_1p9_N_100_trials_100B.npy')

# %%
for r in range(8):
    plt.plot((results[r].T)[13])

# %%
flip= results.T
finalsize = flip[9]
plt.plot(finalsize)
